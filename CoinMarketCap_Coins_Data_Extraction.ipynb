# %%
import requests
import re
from bs4 import BeautifulSoup as b
r=requests.get('https://coinmarketcap.com/').text
soup=b(r,'html.parser')
tbody=soup.tbody
tbody.find_all(class_="sc-aef7b723-0 sc-c745a311-1 ehpgNK")
names=tbody.find_all('p')
for i in tbody:
    print(i.text)
# Out:
# 1BitcoinBTC$30,813.560.25%0.38%1.37%$598.67B$598,670,915,416$13,785,890,794447,224 BTC19,421,325 BTC
# 2EthereumETH$1,927.200.19%0.07%4.25%$231.77B$231,772,731,648$6,578,905,9923,412,297 ETH120,214,105 ETH
# 3TetherUSDT$1.000.01%0.02%0.04%$83.39B$83,385,663,041$23,240,439,94123,232,131,834 USDT83,355,853,919 USDT
# 4BNBBNB$241.320.08%0.50%3.30%$37.61B$37,610,353,359$474,451,2871,966,039 BNB155,850,407 BNB
# 5USD CoinUSDC$1.000.01%0.03%0.01%$27.66B$27,664,598,351$3,336,131,9903,335,492,626 USDC27,659,296,482 USDC
# 6XRPXRP$0.47790.26%2.06%2.24%$24.97B$24,973,958,625$974,611,4802,039,229,397 XRP52,254,289,650 XRP
# 7CardanoADA$0.28810.35%2.18%5.59%$10.07B$10,069,132,291$253,668,515880,631,989 ADA34,955,855,713 ADA
# 8DogecoinDOGE$0.067730.02%1.40%7.60%$9.49B$9,486,467,318$316,050,3334,666,183,876 DOGE140,058,706,384 DOGE
# 9SolanaSOL$19.590.16%1.88%20.51%$7.86B$7,862,446,605$385,814,12119,692,428 SOL401,308,965 SOL
# ...

# %%
# Out:
# 1
# Bitcoin
# BTC
# $598.17B$598,171,829,982
# $13,729,476,249
# 445,764 BTC
# 19,421,243 BTC
# 2
# Ethereum
# ETH
# $231.38B$231,380,477,173
# $6,579,076,255
# 3,418,170 ETH
# 120,214,105 ETH
# 3
# Tether
# USDT
# $83.34B$83,342,563,303
# $23,218,380,442
# 23,222,083,071 USDT
# 83,355,853,919 USDT
# 4
# BNB
# BNB
# $37.67B$37,666,012,976
# $475,660,978
# 1,968,139 BNB
# 155,850,423 BNB
# 5
# USD Coin
# USDC
# $27.67B$27,667,819,385
# $3,346,083,730
# 3,346,828,640 USDC
# 27,673,978,832 USDC
# 6
# XRP
# XRP
# $25.02B$25,022,186,966
# $963,624,423
# 2,012,354,467 XRP
# 52,254,289,650 XRP
# 7
# Cardano
# ADA
# $10.09B$10,085,342,842
# $254,270,889
# 881,304,395 ADA
# 34,955,857,574 ADA
# 8
# Dogecoin
# DOGE
# $9.49B$9,488,206,772
# $317,375,878
# 4,684,857,800 DOGE
# 140,057,586,384 DOGE
# 9
# Solana
# SOL
# $7.87B$7,870,878,531
# $386,875,545
# 19,725,454 SOL
# 401,309,047 SOL
# 10
# Litecoin
# LTC
# $7.62B$7,622,296,520
# $1,206,646,257
# 11,603,722 LTC
# 73,299,864 LTC

# %%
tdata=tbody.find_all('p')

# %%
tdata
# Out:
# [<p class="sc-4984dd93-0 iWSjWE" color="text2" data-sensors-click="true" font-size="14">1</p>,
#  <p class="sc-4984dd93-0 kKpPOn" color="text" data-sensors-click="true" font-size="1" font-weight="semibold">Bitcoin</p>,
#  <p class="sc-4984dd93-0 iqdbQL coin-item-symbol" color="text3" data-sensors-click="true" font-size="1">BTC</p>,
#  <p class="sc-4984dd93-0 jZrMxO" color="text" data-sensors-click="true" font-size="1" style="white-space:nowrap"><span class="sc-f8982b1f-0 jYSZLP">$596.2B</span><span class="sc-f8982b1f-1 bOsKfy" data-nosnippet="true">$596,200,471,525</span></p>,
#  <p class="sc-4984dd93-0 jZrMxO font_weight_500" color="text" data-sensors-click="true" font-size="1">$13,158,617,871</p>,
#  <p class="sc-4984dd93-0 ihZPK" color="text2" data-sensors-click="true" font-size="0">428,642 BTC</p>,
#  <p class="sc-4984dd93-0 WfVLk" color="text" data-sensors-click="true" font-size="1" font-weight="medium">19,421,243 BTC</p>,
# ...

# %%
for name in tdata:
    print(name.text)
# Out:
# 1
# Bitcoin
# BTC
# $596.2B$596,200,471,525
# $13,158,617,871
# 428,642 BTC
# 19,421,243 BTC
# 2
# Ethereum
# ETH
# $231.28B$231,284,221,819
# $6,386,782,472
# 3,319,644 ETH
# 120,214,105 ETH
# 3
# Tether
# USDT
# $83.37B$83,366,118,811
# $22,538,690,673
# 22,535,915,478 USDT
# 83,355,853,919 USDT
# 4
# BNB
# BNB
# $37.67B$37,672,711,245
# $460,651,853
# 1,905,697 BNB
# 155,850,423 BNB
# 5
# USD Coin
# USDC
# $27.67B$27,671,924,884
# $3,308,136,159
# 3,308,381,705 USDC
# 27,673,978,832 USDC
# 6
# XRP
# XRP
# $25.04B$25,041,868,040
# $956,195,091
# 1,995,270,288 XRP
# 52,254,289,650 XRP
# 7
# Cardano
# ADA
# $10.14B$10,138,064,530
# $246,185,058
# 848,841,491 ADA
# 34,955,857,574 ADA
# 8
# Dogecoin
# DOGE
# $9.49B$9,488,574,431
# $315,281,943
# 4,653,768,412 DOGE
# 140,057,586,384 DOGE
# 9
# Solana
# SOL
# $7.91B$7,906,877,424
# $378,218,654
# 19,196,272 SOL
# 401,309,047 SOL
# 10
# Litecoin
# LTC
# $7.66B$7,664,138,030
# $1,173,244,926
# 11,220,922 LTC
# 73,299,864 LTC

# %%
for n in name:
    print(n.text)
