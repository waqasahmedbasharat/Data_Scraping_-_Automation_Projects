# %%
# Dependencies

import time
import os
from datetime import datetime, timedelta
from bs4 import BeautifulSoup
import requests
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.support.ui import Select
#from webdriver_manager.chrome import ChromeDriverManager

from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.support import expected_conditions as EC

import pandas as pd
import os
import shutil
import logging
import xlrd

# Set up selenium options
#chrome_options = Options()
#chrome_options.add_argument("--headless")


# Open the website
url = "https://tessa.energysustainabilityschemes.nsw.gov.au/ipart?id=certificate_batches"
driver=webdriver.Chrome()
driver.get(url)


wait = WebDriverWait(driver, 10)
checkbox = wait.until(EC.presence_of_element_located((By.CSS_SELECTOR, 'input.form-check-input')))

# Check if the checkbox is collapsed
if checkbox.get_attribute("class") == "form-check-input":
    # Click the checkbox
    checkbox.click()

## Selecting fields
# Select "Show filter" 
# Add a time delay of 5 seconds
time.sleep(5)

# Scroll to top of the page, so script and click button
# Scroll the scrollbar to the top of the webpage
driver.execute_script("window.scrollTo(0, 0);")


# Wait for the button to be visible
wait = WebDriverWait(driver, 10)
button = wait.until(EC.visibility_of_element_located((By.ID, "filterToggle")))

# Click the button
button.click()
# # Select "AND" button
# # Website seems corrupt, need to start by clicking AND (and Add condition)
# Add a time delay of 5 seconds
time.sleep(5)
# Wait for the button to be visible using XPath
wait = WebDriverWait(driver, 10)
element = wait.until(EC.visibility_of_element_located((By.XPATH, '//button[contains(@class, "btn-and-condition")]')))
# Perform click action on the button
element.click()
# Select "choose field" dropdown
wait = WebDriverWait(driver, 10)
element = wait.until(EC.visibility_of_element_located((By.XPATH, '//button[contains(text(), "-- choose field --")]')))
# Click on the dropdown button to open the dropdown
element.click()
# Select "Certificate Type"
wait = WebDriverWait(driver, 10)
import time
time.sleep(3)
element = wait.until(EC.visibility_of_element_located((By.XPATH, "//a[text()='Certificate Type']")))
# Perform click action on the option
element.click()
## Select next condition box, select "IS"
# Wait for the desired option in the dropdown to be clickable
option_label = 'is'  # Replace with the desired label of the option you want to select
option_xpath = f"//select[@id='cond_operator_1']/option[text()='{option_label}']"
wait = WebDriverWait(driver, 3)
option_element = wait.until(EC.element_to_be_clickable((By.XPATH, option_xpath)))
# Perform click action on the option
option_element.click()

import re

# Regex pattern to match the select element with "-- None --" option
#pattern = r'<select\b[^>]*>\s*(?:<option\b[^>]*>-- None --<\/option>)'

# Example usage in Selenium
#html = driver.page_source
#select_element_match = re.search(pattern, html)

#if select_element_match:
    # Extract the matched select element from the regex match
    #select_element_html = select_element_match.group(0)
    
    # Create a temporary HTML file with the matched select element
    #with open("temp_select.html", "w", encoding="utf-8") as temp_file:
        #temp_file.write(select_element_html)

    # Now you can use BeautifulSoup to parse the HTML and interact with the element
    #from bs4 import BeautifulSoup

    # Parse the temporary HTML file using BeautifulSoup
    #with open("temp_select.html", "r", encoding="utf-8") as temp_file:
        #soup = BeautifulSoup(temp_file, "html.parser")
    
    # Find the select element using BeautifulSoup
    #select_element_soup = soup.select_one("select")

    # Click on the select element to open the options
    #select_element_soup.click()

    # Wait for the "ESC" option to be visible and clickable
    #option_esc = wait.until(EC.element_to_be_clickable((By.XPATH, "//option[contains(text(), 'ESC')]")))

    # Click the "ESC" option
    #option_esc.click()

    #print("Clicked on the select element and selected 'ESC' option successfully!")

#else:
    #print("Select element with '-- None --' option not found.")

# Close the browser and remove the temporary file

# Wait for the page to load
select_element = wait.until(EC.presence_of_element_located((By.XPATH, "//select[option[contains(text(), '-- None --')]]")))

# Click on the select element to open the options
select_element.click()

time.sleep(2)

try:

    # Find the "ESC" option by its label
    esc_option_element = wait.until(EC.element_to_be_clickable((By.XPATH, '//*[@id="1571-content"]/div/div[1]/fieldset/div/div[3]/ng-switch/label/ng-switch/span/div/span/span/select/option[2]')))

    # Click the "ESC" option using ActionChains
    esc_option_element.click()
    time.sleep(3)

except Exception as e:
    print(f"An error occurred: {e}")
element = wait.until(EC.visibility_of_element_located((By.XPATH, '//button[@class="btn btn-default btn-and-condition add-conditions-row sn-filter-tooltip"]')))
# Perform click action on the button
element.click()
## Select 2nd choose field dropdown "STATUS"
# Note this is same code as prior select drop down, but works on 2nd choose field drop down.
# Select "choose field" dropdown
wait = WebDriverWait(driver, 10)
element = wait.until(EC.visibility_of_element_located((By.XPATH, '//button[contains(text(), "-- choose field --")]')))
# Click on the dropdown button to open the dropdown
element.click()
# Select "Status" by its text
option_xpath = '//a[contains(@class, "ng-binding") and text()="Status"]'
option_element = driver.find_element(By.XPATH, option_xpath)
# Perform click action on the option element
option_element.click()
# Select the desired option in the dropdown by its label
option_label = 'is one of'  # Replace with the desired label of the option you want to select
option_xpath = f"//select[@id='cond_operator_2']/option[text()='{option_label}']"
option_element = driver.find_element(By.XPATH, option_xpath)
option_element.click()


option_element = driver.find_element(By.XPATH, '//*[@id="1571-content"]/div/div[1]/fieldset/div/div[4]/ng-switch/label/ng-switch/span/div/span/span/select/option[2]')
option_element.click()
# # Select the desired option in the dropdown by its label

# option_element = driver.find_element(By.XPATH, '//*[@id="1571-content"]/div/div[1]/fieldset/div/div[4]/ng-switch/label/ng-switch/span/div/span/span/select/option[4]')
# option_element.click()
## Select "Run"
# Wait for the "Run" button to be clickable
button_id = "sn_customerservice_certificate_registry-run-filter-button"
wait = WebDriverWait(driver, 10)
button_element = wait.until(EC.element_to_be_clickable((By.ID, button_id)))
# Perform click action on the "Run" button
button_element.click()
# Out:
# ---------------------------------------------------------------------------
# ConnectionResetError                      Traceback (most recent call last)
# File C:\ProgramData\anaconda3\lib\site-packages\urllib3\connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#
# ...
