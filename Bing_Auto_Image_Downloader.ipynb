# %%
# !pip install bing-image-downloader

# %%
# !mkdir images

# %%
from bing_image_downloader import downloader

downloader.download("clear sea images", limit=1700, output_dir='images')
# Out:
# [%] Downloading Images to /content/images/clear sea images
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 35 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://images6.alphacoders.com/792/thumb-1920-792242.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://jooinn.com/images/clear-blue-sea-2.png
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://images.pexels.com/photos/417063/pexels-photo-417063.jpeg?cs=srgb&amp;dl=pexels-pixabay-417063.jpg&amp;fm=jpg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from https://cdn.wallpapersafari.com/78/51/QUP42Z.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #5 from https://cdn.suwalls.com/wallpapers/beaches/clear-sea-18900-1920x1080.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #6 from https://c.stocksy.com/a/K03300/z9/726536.jpg?1551972042
# [%] File Downloaded !
#
# ...
